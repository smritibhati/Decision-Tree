# %%
import pandas as pd
import numpy as np
eps = np.finfo(float).eps
from numpy import log2
import math
data=pd.read_csv('input_data/decision_Tree/train.csv')
data,testdata= np.split(data,[int(0.80*len(data))])
misclassification = 0
gini=0
normalentropy=0
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8861b4526fcc> in <module>
#       4 from numpy import log2
#       5 import math
# ----> 6 data=pd.read_csv('decision_Tree/train.csv')
#       7 data,testdata= np.split(data,[int(0.80*len(data))])
#       8 misclassification = 0
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'decision_Tree/train.csv' does not exist

# %%
class Node:
    def __init__(self,split,rows,leaf,numeric):
        self.isleaf=leaf
        self.rows=rows
        self.isnumeric=numeric
#         print("rows", rows)
        yes,no = maxfreq(rows)
       
        if yes==0 or no ==0:
            self.isleaf=True
        
        if self.isleaf==True:
            if yes>no:
                self.value=1
            else:
                self.value=0
            self.children={}
        else:
            self.value=split #name of the attribute is the value of the node
            if self.isnumeric:
                self.children,self.minsplit= partitionnumerical(rows,split)
            else:
                self.children= partitioncategorical(rows,split) #all children of this attribute in a dictionary
        print (self.value,"Node Value")
        return

# %%
def maxfreq(rows):
    yes=0
    no=0
    for x in range(len(rows)):
        if rows.iloc[x]['left']==1:
            yes+=1
        else:
            no+=1
    return yes,no

# %%
def partitionnumerical(data, col):
#     print("col",col)
    countdict={}
    minent=float('inf')
    data.sort_values([col],axis=0,ascending=True,inplace=True)
    uniquevalues = data[col].unique()
    for value in uniquevalues:
        ent=0
        data1=data[data[col]<=value]
        data2=data[data[col]>value]
        data1stats = matchlabel(data1)
        data2stats = matchlabel(data2)
        
        ans=0
        for op in data1stats:
            val=data1stats[op]
            ans+= float(val)/float(len(data1)) *(1-float(val)/float(len(data1)))
        
        ent+=ans*(len(data1)/len(data))
       
        ans=0
        for op in data2stats:
            val=data2stats[op]
            ans+= float(val)/float(len(data2)) *(1-float(val)/float(len(data2)))
        
        ent+=ans*(len(data2)/len(data))
    
        if ent<minent:
            minent=ent
            minsplit=value
    
#     print("categorical ent",minent)
#     print("minsplit",minsplit)
#     print("minsplit at",minsplit)
    countdict[0]=data[data[col]<=minsplit]
    countdict[1]=data[data[col]>minsplit]
    return countdict,minsplit

# %%
# Partition function for numerical data while using misclassification

# %%
def mispartitionnumerical(data, col):
#     print("col",col)
    countdict={}
    minent=float('inf')
    data.sort_values([col],axis=0,ascending=True,inplace=True)
    uniquevalues = data[col].unique()
    for value in uniquevalues:
        ent=0
        data1=data[data[col]<=value]
        data2=data[data[col]>value]
        data1stats = matchlabel(data1)
        data2stats = matchlabel(data2)
        
        ans=0
        for op in data1stats:
            val=data1stats[op]
            ans+= min(float(val)/float(len(data1)),(1-float(val)/float(len(data1))))
        
        ent+=ans*(len(data1)/len(data))
       
        ans=0
        for op in data2stats:
            val=data2stats[op]
            ans+= min(float(val)/float(len(data2)),(1-float(val)/float(len(data2))))
        
        ent+=ans*(len(data2)/len(data))
    
        if ent<minent:
            minent=ent
            minsplit=value
    
#     print("categorical ent",minent)
#     print("minsplit",minsplit)
#     print("minsplit at",minsplit)
    countdict[0]=data[data[col]<=minsplit]
    countdict[1]=data[data[col]>minsplit]
    return countdict,minsplit

# %%
#partitions the rows into multiple groups based on the column passed
def partitioncategorical(data,col):
    countdict={}
    uniquevalues = data[col].unique()
    for value in uniquevalues:
        countdict[value]= data[data[col]==value]
#     print (countdict)
    return countdict

# %%
#matches the passed rows to count the number of yes and no in the rows 
def matchlabel(data):
    stats={}
    values, valuecount = np.unique(data['left'],return_counts=True)
    for i in range(len(values)):
        stats[values[i]]=valuecount[i]
    return stats

# %%
def isnumeric(col):
    return data[col].dtype.kind in 'bifc'

# %%
#calculate the entropy of the passed column
def entropy(rows,col):
    entro=0
    
    if isnumeric(col):
#         print(col,"is numeric")
        countdict,minsplit = partitionnumerical(rows,col)
    else:
        countdict= partitioncategorical(rows,col)
    
#     print("countdict",countdict)
    for key in countdict:
        rowgroup=countdict[key]
        rowgroupstats=matchlabel(rowgroup)
        ans=0
#         print(rowgroupstats)
        for op in rowgroupstats:
            value=rowgroupstats[op]
            ans+= float(value)/float(len(rowgroup)) * (1- float(value)/float(len(rowgroup)))
        
        entro+=ans*(len(rowgroup)/len(rows))
    return entro

# %%
def misentropy(rows,col):
    entro=0
    
    if isnumeric(col):
#         print(col,"is numeric")
        countdict,minsplit= mispartitionnumerical(rows,col)
    else:
        countdict= partitioncategorical(rows,col)
    
#     print("countdict",countdict)
    for key in countdict:
        rowgroup=countdict[key]
        rowgroupstats=matchlabel(rowgroup)
        ans=0
#         print(rowgroupstats)
        for op in rowgroupstats:
            value=rowgroupstats[op]
            ans+= min(float(value)/float(len(rowgroup)),(1- float(value)/float(len(rowgroup))))
        
        entro+=ans*(len(rowgroup)/len(rows))
    return entro

# %%
def totalgini(data):
    countdict= partitioncategorical(data,'left')
    total = 0
    for key in countdict:
        value=len(countdict[key])
        total+= float(value)/float(len(data)) * (1-float(value)/float(len(data)))
#     print (total)
    return total

# %%
totalgini(data)
# Out:
# 0.36158826826494894

# %%
def totalmis(data):
    countdict=partitioncategorical(data,'left')
    total = 0
    for key in countdict:
        value=len(countdict[key])
        total+= min(float(value)/float(len(data)),(1-float(value)/float(len(data))))
#     print (total)
    return total

# %%
totalmis(data)
# Out:
# 0.47385984427141264

# %%
def informationgain(data,total):
#     print("length of data", len(data))
    maxinfogain=0
    attr=0
    infogain=0
    for col in data:
        if col=='left': 
            continue
        ent=entropy(data,col)
#         print("Total and entropy",total,ent)
        infogain=total-ent
#         print ("infogain",infogain)
        if infogain>maxinfogain:
#             print(maxinfogain)
            maxinfogain=infogain
            attr=col
    
    print ("maxinfogain",maxinfogain)
    return maxinfogain,attr

# %%
level=0
def buildTree(data):
#     global level
    total=totalgini(data)
#     print(total,"total")
    gain, split = informationgain(data,total)
    print("split", split)
#     level+=1
    if gain<=0:
        return Node(split,data,True,False)
    
    root = Node(split,data,False,isnumeric(split))
#     print( "root->children",root.children)
    for child in root.children:
#         print(root.children[child].drop(columns=[split]))
        if(isnumeric(split)):
            root.children[child]=buildTree(root.children[child])
        else:
            root.children[child]=buildTree(root.children[child].drop(columns=[split]))
        
#     level-=1
    return root

# %%
root=buildTree(data)
# print(root.isleaf)
# Out:
# maxinfogain 0.10484932317586415
# split satisfaction_level
# satisfaction_level Node Value
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# maxinfogain 0.10990466505489394
# split number_project
# number_project Node Value
# maxinfogain 0.10581600859671964
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.039059787940953265
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.01960232619685944
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.013079586094564163
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.21875
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.008751762080037608
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 7.32459167241354e-05
# split salary
# salary Node Value
# maxinfogain 5.066808847528203e-05
# split last_evaluation
# last_evaluation Node Value
# maxinfogain
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.40816326530612246
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.0033443489514671243
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.09421568627450982
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.11072664359861592
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.4444444444444445
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.0035502958579881755
# split number_project
# number_project Node Value
# maxinfogain 0.0005193699446572747
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.06658739595719378
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.02821869488536155
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.02721088435374154
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.4444444444444445
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.4444444444444445
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.09182736455463725
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.34435261707988984
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.2777777777777778
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.02948979591836734
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.021764900076473165
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.009924385633270305
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.375
# split sales
# sales Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.05298440875363952
# split sales
# sales Node Value
# maxinfogain 0.16071428571428573
# split time_spend_company
# time_spend_company Node Value
# maxinfogain 0.26122448979591834
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.32
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.19753086419753085
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.4444444444444445
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.4897959183673469
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.375
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.11111111111111113
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.5
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.19831798023387087
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.007467805740257516
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.0063043192586512975
# split sales
# sales Node Value
# maxinfogain 0.008641641911963233
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.1130298273155417
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.14201183431952658
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.12918108419838525
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.4444444444444445
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.0722341674471369
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.022042017596042435
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.1519588444796201
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.4897959183673469
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.09339577012707213
# split salary
# salary Node Value
# maxinfogain 0.32
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.13775510204081629
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.375
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.024305555555555518
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.4444444444444445
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.07438016528925623
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.5
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.0929557007988381
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.012687427912341398
# split number_project
# number_project Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.11111111111111113
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.5
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.16875
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.3085714285714285
# split time_spend_company
# time_spend_company Node Value
# maxinfogain 0.24489795918367352
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.18747120287410665
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.035720395951469225
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.018993715948887435
# split time_spend_company
# time_spend_company Node Value
# maxinfogain 0.13698529411764707
# split number_project
# number_project Node Value
# maxinfogain 0.20919426594167073
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.24489795918367352
# split sales
# sales Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.1422222222222222
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.0864197530864198
# split sales
# sales Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.5
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.003193113980285999
# split number_project
# number_project Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.2777777777777778
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.32
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.0912309686629442
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.06721446092623198
# split number_project
# number_project Node Value
# maxinfogain 0.375
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.016444093134195925
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.01999999999999999
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.4444444444444445
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.1499013806706114
# split sales
# sales Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.4444444444444445
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.4444444444444445
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0.06784703537955669
# split number_project
# number_project Node Value
# maxinfogain 0.08677685950413219
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.03006218075041763
# split time_spend_company
# time_spend_company Node Value
# maxinfogain 0.011709845580377895
# split number_project
# number_project Node Value
# maxinfogain 0.0039588479563601
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.0004390083727995042
# split sales
# sales Node Value
# maxinfogain 0.001430947770750285
# split last_evaluation
# last_evaluation Node Value
# maxinfogain 0.18
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.000354855549906722
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.009349890430971466
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0.32
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.0015978816654492745
# split average_montly_hours
# average_montly_hours Node Value
# maxinfogain 0.09375
# split number_project
# number_project Node Value
# maxinfogain 0.5
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.0232525951557093
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0.18
# split satisfaction_level
# satisfaction_level Node Value
# maxinfogain 0
# split 0
# 1 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value
# maxinfogain 0
# split 0
# 0 Node Value

# %%
def findlabel(row):
    ptr = root
    while ptr.isleaf==False:
        if ptr.isnumeric==False:
            try:
                value=row[ptr.value]
#                 print(ptr.children)
                ptr=ptr.children[value]
            except:
                return 0
        else:
            try:
                value=row[ptr.value]
                if value<=ptr.minsplit:
                    ptr=ptr.children[0]
                else:
                    ptr=ptr.children[1]
            except:
                return 0
    
    return ptr.value

# %%
def calculate(fp,fn,tp,tn,wrong,correct):
    gini=correct/(wrong+correct)
    recall=tp/(tp+fn)
    precision=tp/(tp+fp)
    f1score=(2/(1/precision)+(1/recall))
    return gini,recall,precision,f1score

# %%
def predict(data):
    correct=0
    wrong=0
    fp=0
    tp=0
    fn=0
    tn=0
    for i in range(0,len(data)):
        row=data.iloc[i]
        predictlabel=findlabel(row)
        if predictlabel==row['left']:
            if predictlabel==1:
                tp+=1
            else:
                tn+=1
            correct+=1
        else:
            if predictlabel==0:
                fn+=1
            else:
                fp+=1
            wrong+=1
    print(fp,fn,tp,tn,wrong,correct)
    calculate(fp,fn,tp,tn,wrong,correct)

# %%
predict(testdata)
# Out:
# 34 18 527 1669 52 2196
