# %%
import pandas as pd
import numpy as np
import math
data=pd.read_csv('decision_Tree/train.csv')

# %%
# Divide the data into training and validation. Drop all non categorical columns from the dataframe

# %%
data,testdata= np.split(data,[int(0.80*len(data))])
data= pd.DataFrame(data,columns=['Work_accident', 'promotion_last_5years', 'sales', 'salary', 'left'])

# %%
# Node class is defines a node in the decision tree. Every node has the following properties:
#     isleaf : if the node is a leaf
#     isnumeric : if the node determines a numerical column
#     value : the name of the column on which this node is split
#     children : a dictionary of all the children nodes of this node

# %%
class Node:
    def __init__(self,split,rows,leaf):
        self.isleaf=leaf
        self.rows=rows
#         print("rows", rows)
        yes,no = maxfreq(rows)
       
        if yes==0 or no ==0:
            self.isleaf=True
        
        if self.isleaf==True:
            if yes>no:
                self.value=1
            else:
                self.value=0
            self.children={}
        else:
            self.value=split #name of the attribute is the value of the node
            self.children= partition(rows,split) #all children of this attribute in a dictionar
        print (self.value,"Node Value")
        return

# %%
# Given a dataframe, counts the number of yes and nos labels

# %%
def maxfreq(rows):
    yes=0
    no=0
    for x in range(len(rows)):
        if rows.iloc[x]['left']==1:
            yes+=1
        else:
            no+=1
    return yes,no

# %%
# partitions the rows into multiple groups based on the column passed

# %%
def partition(data,col):
    countdict={}
    uniquevalues = data[col].unique()
    for value in uniquevalues:
        countdict[value]= data[data[col]==value]
#     print (countdict)
    return countdict

# %%
#matches the passed rows to count the number of yes and no in the rows

# %%
def matchlabel(data):
    stats={}
    values, valuecount = np.unique(data['left'],return_counts=True)
    for i in range(len(values)):
        stats[values[i]]=valuecount[i]
    return stats

# %%
#calculate the entropy of the passed column

# %%
def entropy(rows,col):
    entro=0
    countdict= partition(rows,col)
    for key in countdict:
        rowgroup=countdict[key]
        rowgroupstats=matchlabel(rowgroup)
        ans=0
#         print(rowgroupstats)
        for op in rowgroupstats:
            value=rowgroupstats[op]
            ans-= float(value)/float(len(rowgroup)) * math.log((float(value)/float(len(rowgroup))),2)
        
        entro+=ans*(len(rowgroup)/len(rows))
    return entro

# %%
# calculates the total entropy of the data on the last column

# %%
def totalentropy(data):
    countdict=partition(data,'left')
    total = 0
    for key in countdict:
        value=len(countdict[key])
        total-= float(value)/float(len(data)) * math.log((float(value)/float(len(data))),2)
    return total

# %%
# Runs on all the columns of the data, and returns the max infogain and the column name for that max infogain

# %%
def informationgain(data):
    global totalentropy
    print("length of data", len(data))
    maxinfogain=0
    attr=0
    infogain=0
    for col in data:
        if col=='left': 
            continue
        ent=entropy(data,col)
        
        infogain=totalentropy(data)-ent
        print (infogain)
        if infogain>maxinfogain:
#             print(maxinfogain)
            maxinfogain=infogain
            attr=col
    return maxinfogain,attr

# %%
# A recursive funtion to build the tree.
# Initially called with the complete data.
# Recursive calls are made while the data is continuously partitiones and columns are dropped.
# Condition for leaf node: Gain<=0 or if there is only one label in the data

# %%
def buildTree(data):
    global level
    gain, split = informationgain(data)
    print("split", split)
    if gain<=0:
        return Node(split,data,True)
    
    root = Node(split,data,False)
    for child in root.children:
        root.children[child]=buildTree(root.children[child].drop(columns=[split]))
        
    return root

# %%
root=buildTree(data)
# print(root.isleaf)
# Out:
# length of data 8990
# 0.020558510128864893
# 0.003521395359342483
# 0.005218505255884964
# 0.01945576326635856
# split Work_accident
# Work_accident Node Value
# length of data 7665
# 0.004256241460114385
# 0.005533447440471573
# 0.021670589216258196
# split salary
# salary Node Value
# length of data 3756
# 0.0007932346054907446
# 0.009845239964154873
# split sales
# sales Node Value
# length of data 1107
# 0.0012259300830442799
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 1100
# split 0
# 0 Node Value
# length of data 7
# split 0
# 0 Node Value
# length of data 185
# 0.0028817594653642864
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 184
# split 0
# 0 Node Value
# length of data 1
# split 0
# 0 Node Value
# length of data 690
# 0.00022360633333740054
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 685
# split 0
# 0 Node Value
# length of data 5
# split 0
# 0 Node Value
# length of data 93
# 0.0
# split 0
# 0 Node Value
# length of data 320
# 0.005491986997563925
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 319
# split 0
# 0 Node Value
# length of data 1
# split 0
# 1 Node Value
# length of data 254
# 0.0
# split 0
# 0 Node Value
# length of data 166
# 0.0029805392127457697
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 164
# split 0
# 0 Node Value
# length of data 2
# split 0
# 0 Node Value
# length of data 195
# 0.019054093261863914
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 189
# split 0
# 0 Node Value
# length of data 6
# split 0
# 0 Node Value
# length of data 575
# 0.0034737408734534236
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 572
# split 0
# 0 Node Value
# length of data 3
# split 0
# 0 Node Value
# length of data 171
# 0.0032131236585922762
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 170
# split 0
# 0 Node Value
# length of data 1
# split 0
# 0 Node Value
# length of data 3286
# 0.005601200358511194
# 0.012465421087409223
# split sales
# sales Node Value
# length of data 896
# 0.0102891228582761
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 866
# split 0
# 0 Node Value
# length of data 30
# split 0
# 0 Node Value
# length of data 593
# 0.006260257340166997
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 585
# split 0
# 0 Node Value
# length of data 8
# split 0
# 0 Node Value
# length of data 194
# 0.019713970452193696
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 184
# split 0
# 0 Node Value
# length of data 10
# split 0
# 0 Node Value
# length of data 281
# 0.008702414002487835
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 280
# split 0
# 0 Node Value
# length of data 1
# split 0
# 1 Node Value
# length of data 186
# 0.01949468235099705
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 174
# split 0
# 0 Node Value
# length of data 12
# split 0
# 0 Node Value
# length of data 193
# 0.018381615847041455
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 5
# split 0
# 0 Node Value
# length of data 188
# split 0
# 0 Node Value
# length of data 191
# 0.0
# split 0
# 0 Node Value
# length of data 466
# 0.0006358042188582269
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 459
# split 0
# 0 Node Value
# length of data 7
# split 0
# 0 Node Value
# length of data 170
# 0.005811730823511163
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 168
# split 0
# 0 Node Value
# length of data 2
# split 0
# 0 Node Value
# length of data 116
# 0.02287666493151974
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 105
# split 0
# 0 Node Value
# length of data 11
# split 0
# 0 Node Value
# length of data 623
# 0.006021590827621381
# 0.036138420554504
# split sales
# sales Node Value
# length of data 42
# 0.0034816329709856375
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 38
# split 0
# 0 Node Value
# length of data 4
# split 0
# 0 Node Value
# length of data 80
# 0.0
# split 0
# 0 Node Value
# length of data 97
# 0.0
# split 0
# 0 Node Value
# length of data 143
# 0.004022757149482525
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 137
# split 0
# 0 Node Value
# length of data 6
# split 0
# 0 Node Value
# length of data 44
# 0.0
# split 0
# 0 Node Value
# length of data 106
# 0.0023914708757451913
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 89
# split 0
# 0 Node Value
# length of data 17
# split 0
# 0 Node Value
# length of data 34
# 0.0
# split 0
# 0 Node Value
# length of data 23
# 0.012280723905402358
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 22
# split 0
# 0 Node Value
# length of data 1
# split 0
# 0 Node Value
# length of data 23
# 0.0
# split 0
# 0 Node Value
# length of data 31
# 0.0
# split 0
# 0 Node Value
# length of data 1325
# 9.22813566112124e-06
# 0.0030894994215478477
# 0.012756609656143225
# split salary
# salary Node Value
# length of data 649
# 0.002648528066811151
# 0.00518515610405107
# split sales
# sales Node Value
# length of data 46
# 0.0
# split 0
# 0 Node Value
# length of data 179
# 0.03636572997105808
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 174
# split 0
# 0 Node Value
# length of data 5
# split 0
# 1 Node Value
# length of data 42
# 0.0034364208708378974
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 40
# split 0
# 0 Node Value
# length of data 2
# split 0
# 0 Node Value
# length of data 112
# 0.002432293563562671
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 110
# split 0
# 0 Node Value
# length of data 2
# split 0
# 0 Node Value
# length of data 43
# 0.002456172921290023
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 42
# split 0
# 0 Node Value
# length of data 1
# split 0
# 0 Node Value
# length of data 113
# 0.0
# split 0
# 0 Node Value
# length of data 40
# 0.0
# split 0
# 0 Node Value
# length of data 28
# 0.0
# split 0
# 0 Node Value
# length of data 26
# 0.0
# split 0
# 0 Node Value
# length of data 20
# 0.03838971020210813
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 17
# split 0
# 0 Node Value
# length of data 3
# split 0
# 0 Node Value
# length of data 543
# 0.0012379548476542102
# 0.017772115650701137
# split sales
# sales Node Value
# length of data 87
# 0.0016093011462433582
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 86
# split 0
# 0 Node Value
# length of data 1
# split 0
# 0 Node Value
# length of data 39
# 0.0
# split 0
# 0 Node Value
# length of data 95
# 0.0015199094849089323
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 94
# split 0
# 0 Node Value
# length of data 1
# split 0
# 0 Node Value
# length of data 157
# 0.00029022805809303387
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 143
# split 0
# 0 Node Value
# length of data 14
# split 0
# 0 Node Value
# length of data 21
# 0.014489936607308906
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 19
# split 0
# 0 Node Value
# length of data 2
# split 0
# 0 Node Value
# length of data 19
# 0.004220579197929009
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 18
# split 0
# 0 Node Value
# length of data 1
# split 0
# 0 Node Value
# length of data 32
# 0.0061230974627376755
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 28
# split 0
# 0 Node Value
# length of data 4
# split 0
# 0 Node Value
# length of data 25
# 0.0
# split 0
# 0 Node Value
# length of data 35
# 0.013117702960063538
# split promotion_last_5years
# promotion_last_5years Node Value
# length of data 33
# split 0
# 0 Node Value
# length of data 2
# split 0
# 0 Node Value
# length of data 33
# 0.0
# split 0
# 0 Node Value
# length of data 133
# 0.0
# 0.0
# split 0
# 0 Node Value

# %%
def findlabel(row):
    ptr = root
    while ptr.isleaf==False:
        value=row[ptr.value]
#         print(value)
        ptr=ptr.children[value]
    return ptr.value

# %%
def calculate(fp,fn,tp,tn,wrong,correct):
    accuracy=correct/(wrong+correct)
    recall=tp/(tp+fn)
    precision=tp/(tp+fp)
    f1score=(2/(1/precision)+(1/recall))
    return accuracy,recall,precision,f1score

# %%
def predict(data):
    correct=0
    wrong=0
    fp=0
    tp=0
    fn=0
    tn=0
    for i in range(0,len(data)):
        row=data.iloc[i]
        predictlabel=findlabel(row)
        if predictlabel==row['left']:
            if predictlabel==1:
                tp+=1
            else:
                tn+=1
            correct+=1
        else:
            if predictlabel==0:
                fn+=1
            else:
                fp+=1
            wrong+=1
#     print(fp,fn,tp,tn,wrong,correct)
    return (calculate(fp,fn,tp,tn,wrong,correct))

# %%
accuracy, recall, precision, F1score = predict(testdata)
print(accuracy,recall,precision,F1score)
# Out:
# 0.7580071174377224 0.001834862385321101 1.0 547.0
